# %% [markdown]
# # Unión de Datos Nuevos

# %%
import pandas as pd
from IPython.display import display
import numpy as np
df_0 = pd.read_excel('datos_CAIMEDv8_fixed.xlsx')
df_1 = pd.read_excel('external_data.xlsx')

# %%
df_0['individuo'] = df_0['individuo'].astype(int)
df_1['cedula'] = df_1['cedula'].astype(int)

# %%
df_1
# Out:
#                  Nombres y apellidos    cedula      edad  ciudad        sexo  \
# 0           Yolima Dueñas Albarracin  47427055        61   YOPAL    Femenino
# 1                     Gustavo Barona   6301768        66  IBAGUE   Masculino
# 2               David Rivas Barragan   2374303        73  IBAGUE   Masculino
# 3                    Alejandro Palma   2315455        93  IBAGUE   Masculino
# 4                      Jorge Salazar  14319350        55  IBAGUE   Masculino
# ..                               ...       ...       ...     ...         ...
# 969  OLGA AMELIA   TRUJILLO VELANDIA  47425710  54 AÑOS    YOPAL   FEMENINO
# 970            CELIA PEREZ RODRIGUEZ  23738879  81 AÑOS    YOPAL   FEMENINO
# 971      JOSE NICANOR SIGUA GUALDRON   1167028  78 AÑOS    YOPAL  MASCULINO
# 972       MIGUEL ANGEL  ZERPA LORETO   5614392  55 AÑOS    YOPAL  MASCULINO
# 973    NANCY MERCEDES MORALES PARADA  23709564  64 AÑOS    YOPAL   FEMENINO
#
#     Diabetico        Tiempo de DM Hipertensión  Hipercolesterolemia familiar  \
# 0          No                 NaN            Si                           Si
# 1          No                 NaN            Si                           No
# 2          No                 NaN            Si                           No
# 3          Si  Entre 10 y 20 años            Si                           No
# 4          No                 NaN            Si                           No
# ..        ...                 ...           ...                          ...
# 969        Si                 NaN            Si                           No
# 970        No                 NaN            Si                           No
# 971        No                 NaN            Si                           No
# 972        No                 NaN            Si                           No
# 973        Si                 NaN            Si                           No
#
#     ERCoDialisis Ultimo Rango de Colesterol total Enfermedad  relevante  \
# 0             No                      Desconocido                    Si
# 1             No                      Desconocido                    Si
# 2             No                      Desconocido                    Si
# 3             No                      Desconocido                    Si
# 4             No                      Desconocido                    Si
# ..           ...                              ...                   ...
# 969           No                              NA                     Si
# 970           No                              NaN                    Si
# 971           No                              NA                     Si
# 972           No                              NA                     Si
# 973           No                              NaN                    Si
#
#     Infarto agudo al miocardio ACV Enf Arterial Angina Inestable  \
# 0                           No  No           No               No
# 1                           Si  No           No               No
# 2                           Si  No           No               No
# 3                           Si  No           No               No
# 4                           Si  No           No               No
# ..                         ...  ..          ...              ...
# 969                         Si  No           No               No
# 970                         Si  No           No               No
# 971                         Si  No           No               No
# 972                         Si  No           No               No
# 973                         No  Si           No               No
#
#     Angina Estble Cateterismo cardiaco Enfermedad arterial periférica
# 0              No                   Si                             No
# 1              No                   Si                             No
# 2              No                   No                             No
# 3              No                   No                             No
# 4              No                   No                             No
# ..            ...                  ...                            ...
# 969            No                   No                             No
# 970            No                   No                             No
# 971            No                   No                             No
# 972            No                   No                             No
# 973            No                   No                             No
#
# [974 rows x 19 columns]

# %%
i = 0
for ced in df_1['cedula']:
    if ced not in list(df_0['individuo'].astype(int)):
        i += 1
        print('eroor', ced)
print(i, 'en total')
# Out:
# eroor 7530382
# eroor 17412049
# eroor 22229512
# eroor 41783045
# eroor 6504609
# eroor 65496684
# eroor 40315034
# eroor 28837359
# eroor 38233613
# eroor 28814071
# eroor 79245518
# eroor 18435275
# eroor 15895374
# eroor 69061001
# eroor 24477337
# eroor 79314863
# eroor 20438765
# eroor 17591769
# eroor 3297269
# eroor 19252859
# eroor 23738879
# 21 en total

# %%
column_names = list(df_1.columns)

# %%
dx= {}
for name in column_names:
    dx[name] = []
for row_a in range(len(df_0)):
    founded = False
    index_founded = None
    current_ced  = (df_0.iloc[row_a])['individuo']
    if current_ced in list(df_1['cedula']):
        for column in column_names:
            if column == 'cedula':
                dx[column].append(int(str(current_ced).replace('.','')))
            else:
                dx[column].append(  list(df_1[df_1['cedula']==current_ced][column])[0]     )
    else:
        for column in column_names:
            dx[column].append('')

# %%
dx = pd.DataFrame(dx)

# %%
dx['sexo']
# Out:
# 0      Masculino
# 1       Femenino
# 2      Masculino
# 3       Femenino
# 4      Masculino
#          ...
# 982    Masculino
# 983     Femenino
# 984    Masculino
# 985    Masculino
# 986     Femenino
# Name: sexo, Length: 987, dtype: object

# %%
len(dx) == len(df_0)
# Out:
# True

# %%
dx_2= {}
i = 0
aaa = {0:'a',
       1:'b'}
for name in (list(dx.columns) + list(df_0.columns)):
    if 'sexo' == name:
        dx_2[f'{name}_{aaa[i]}'] = []
        i+= 1
    dx_2[name] = []
for index in range(len(df_0)):
    for name in list(df_0.columns):
        if name == 'sexo':
            dx_2['sexo_a'].append((df_0.iloc[index])['sexo'])
        else:
            dx_2[name].append((df_0.iloc[index])[name])
    for name2 in dx.columns:
        if name2 == 'sexo':
            dx_2['sexo_b'].append((dx.iloc[index])['sexo'])
        else:
            dx_2[name2].append((dx.iloc[index])[name2])

# %%
dx_2['sexo'] = dx_2['sexo_a']

# %%
pd.DataFrame(dx_2).to_excel('datos_CAIMEDv8_unido.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd.DataFrame(dx_2).to_excel('datos_CAIMEDv8_unido.xlsx',index=False)
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\io\formats\excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\io\excel\_base.py:1263, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1259 self._handles = IOHandles(
#    1260     cast(IO[bytes], path), compression={"compression": None}
#    1261 )
#    1262 if not isinstance(path, ExcelWriter):
# -> 1263     self._handles = get_handle(
#    1264         path, mode, storage_options=storage_options, is_text=False
#    1265     )
#    1266 self._cur_sheet = None
#    1268 if date_format is None:
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'datos_CAIMEDv8_unido.xlsx'
