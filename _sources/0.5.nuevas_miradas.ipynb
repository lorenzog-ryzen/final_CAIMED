# %%
cedulas = [3297269,
 6504609,
 7530382,
 15895374,
 17412049,
 17591769,
 18435275,
 19252859,
 20438765,
 22229512,
 23738879,
 24477337,
 28814071,
 28837359,
 38233613,
 40315034,
 41783045,
 65496684,
 69061001,
 79245518,
 79314863]

# %%
[3297269, 6504609, 7530382, 15895374, 17412049, 17591769, 18435275, 19252859, 20438765, 22229512, 23738879, 24477337, 28814071, 28837359, 36233613, 40315034, 41783045, 5496684, 69061001, 79245518, 79314863]

# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_excel('datos_CAIMEDv7.xlsx')
df2 = pd.read_excel('datos_CAIMEDv8_unido_v2.xlsx')

# %%
len(df)
# Out:
# 1007

# %%
no = []
si = []
for ced in cedulas :
    if ced in list(df['individuo']):
        si.append(ced)
        pass
    else:
        print(ced)
        no.append(ced)
# Out:
# 22229512
# 24477337
# 69061001

# %%
si
# Out:
# [3297269,
#  6504609,
#  7530382,
#  15895374,
#  17412049,
#  17591769,
#  18435275,
#  19252859,
#  20438765,
#  23738879,
#  28814071,
#  28837359,
#  38233613,
#  40315034,
#  41783045,
#  65496684,
#  79245518,
#  79314863]

# %%
for n in si:
    display()

# %%
len(cedulas)-len(no)
# Out:
# 18

# %%
taking = [20438765, 17591769, 41783045, 28837359, 3297269, 79314863] + [23738879, 19252859, 18435275, 15895374, 28814071, 6504609, 38233613, 4000000] +[19062972, 65496684, 7530382] + [79245518, 17412049, 40315034]

# %%
ind = 0
for i in taking:
    if i in si:
        print(i)
        ind += 1
print(ind)
# Out:
# 20438765
# 17591769
# 41783045
# 28837359
# 3297269
# 79314863
# 23738879
# 19252859
# 18435275
# 15895374
# 28814071
# 6504609
# 38233613
# 65496684
# 7530382
# 79245518
# 17412049
# 40315034
# 18
