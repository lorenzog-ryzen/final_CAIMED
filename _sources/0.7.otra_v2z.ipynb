# %% [markdown]
# # Trigliceridos

# %%
import pandas as pd
import numpy  as np
from IPython.display  import display

# %%
df      = pd.read_excel('Data_copy_changes.xlsx')
df_1    = pd.read_excel('datos_CAIMEDvXII.xlsx')

# %%
grd = None
for i in df:
    if 'rigli' in i:
        grd = i
display(df[grd])        
df[grd] = df[grd].astype(str)
# Out:
# 0       198
# 1        80
# 2       160
# 3        83
# 4        81
#        ...
# 1002    196
# 1003    385
# 1004     83
# 1005    163
# 1006    203
# Name: Trigliceridos (mg/dl) Alerta: Valores menores a 45mg/dL y valores mayores a 650ml/dL son reportados o se reportan como fuera de rango., Length: 1007, dtype: object

# %%
for index, value in enumerate(df[grd]):
    if len(value)>=4:
        print(index, value)
# Out:
# 99 508
# 280 Fuera de rango (>650 mg/dl))
# 663 Fuera de rango del limite de detección máximo (Mayor a 650)
# 938 Fuera de rango del límite de detección máximo: mayor a 650
# 979 fuera de rango

# %%
df[grd] = df[grd].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df[grd] = df[grd].astype(float)
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...

# %%
for index in range(len(df)):
    row =  df[grd].iloc[ index ]
    if row > 650: print(df[grd].iloc[ index ])
# Out:
# 700.0
# 700.0
# 700.0
# 700.0

# %%
df[grd]
# Out:
# 0       198.0
# 1        80.0
# 2       160.0
# 3        83.0
# 4        81.0
#         ...
# 1002    196.0
# 1003    385.0
# 1004     83.0
# 1005    163.0
# 1006    203.0
# Name: Trigliceridos (mg/dl) Alerta: Valores menores a 45mg/dL y valores mayores a 650ml/dL son reportados o se reportan como fuera de rango., Length: 1007, dtype: float64

# %%
df_1['trigliceridos(mg/dl)'] = triglic
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df_1['trigliceridos(mg/dl)'] = triglic
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
#    4301     ensure homogeneity.
#    4302     """
# -> 4303     value, refs = self._sanitize_column(value)
#    4305     if (
#    4306         key in self.columns
#    4307         and value.ndim == 1
# ...

# %%
df.to_excel('CAIMEDvEXTERNAL2.xlsx',index=False)

# %%
df['Individuo'] = (df['Individuo']).astype(int)

# %%
vct_triglic =  [None]*len(df_1)
for index in range(len(df_1)):
    ced_final =  (df_1.iloc[index])['cedula']
    vct_triglic[index] = float((df[df['Individuo']==ced_final])[grd])
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_25332\445494529.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   vct_triglic[index] = float((df[df['Individuo']==ced_final])[grd])

# %%
df_1['trigliceridos(mg/dl)'] = vct_triglic

# %%
df_1.to_excel('datos_CAIMEDvXII_trigliceridos.xlsx',index=False)
