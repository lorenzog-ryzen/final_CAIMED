# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import plotly.express    as pxs
import plotly.graph_objects as go
import altair            as alt
import datos
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import plotly.express as px
import altair as alt
import datos
import plotly.graph_objects as go

# %%
for i in datos.datos:
    if 'trig' in i:
        print(i)
# Out:
# trigliceridos(mg/dl)

# %% [markdown]
# - cLDL(mg/dl)
# - HDL(mg/dl)
# - trigliceridos(mg/dl)

# %%
fig = px.box(datos.datos, x='presion_arterial_diastolica', y='sexo', 
                         title=f'Boxplot de presión arterial diastólica por sexo')
fig.update_layout(xaxis_title='Presión Arterial Diastólica', yaxis_title='sexo')
fig.show()
